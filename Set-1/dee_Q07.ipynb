# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create a Perceptron classifier
perceptron = Perceptron(max_iter=1000, random_state=42)

# Train the Perceptron without normalization
perceptron.fit(X_train, y_train)

# Plot the convergence curve without normalization
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(perceptron.coef_) + 1), perceptron.coef_, label='Without Normalization')
plt.xlabel('Iterations')
plt.ylabel('Coefficients')
plt.title('Convergence of Perceptron without Normalization')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Make predictions on the test set without normalization
y_pred = perceptron.predict(X_test)

# Evaluate the model without normalization
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy without Normalization:", accuracy)
# Out:
# Accuracy without Normalization: 0.4666666666666667

# %%
# Normalize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a new Perceptron classifier
perceptron_norm = Perceptron(max_iter=1000, random_state=42)

# Train the Perceptron with normalized features
perceptron_norm.fit(X_train_scaled, y_train)

# Plot the convergence curve with normalization
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(perceptron_norm.coef_[0]) + 1), perceptron_norm.coef_[0], label='With Normalization')
plt.xlabel('Iterations')
plt.ylabel('Coefficients')
plt.title('Convergence of Perceptron with Normalization')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Make predictions on the normalized test set
y_pred_norm = perceptron_norm.predict(X_test_scaled)

# Evaluate the model with normalization
accuracy_norm = accuracy_score(y_test, y_pred_norm)
print("Accuracy with Normalization:", accuracy_norm)
# Out:
# Accuracy with Normalization: 0.8888888888888888
