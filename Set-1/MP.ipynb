# %%
import pandas as pd
import numpy as np
import random

# %%
rand_data = []

for i in range(1000):
    rand_data.append([random.randint(25,50), random.randint(10, 250) *10000, random.randint(2,6), random.randint(0,1)])

df = pd.DataFrame(rand_data, columns=['Age', 'Salary', 'CountFamilyMembers', 'BuysFlat'])
display(df)
# Out:
#      Age   Salary  CountFamilyMembers  BuysFlat
# 0     30   290000                   5         1
# 1     33   280000                   3         0
# 2     32   140000                   5         1
# 3     35  1730000                   4         0
# 4     31   610000                   5         0
# ..   ...      ...                 ...       ...
# 995   28  1340000                   6         0
# 996   33   370000                   6         0
# 997   47  1510000                   2         0
# 998   47  1040000                   4         1
# 999   30  1910000                   3         0
#
# [1000 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('BuysFlat', axis=1)
Y=df['BuysFlat']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3, stratify=Y)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
X_binarised_train=X_train.apply(pd.cut , bins=2, labels=[1,0])

# %%
X_binarised_test = X_test.apply(pd.cut, bins=2, labels=[1, 0])
X_binarised_test = X_binarised_test.values
X_binarised_train = X_binarised_train.values

# %%
from sklearn.metrics import accuracy_score

# %%
class MPNeuron:

    def __init__(self):
        self.b = None

    def model(self, x):
        return(sum(x) >= self.b)

    def predict(self, X):
        Y = []
        for x in X:
            result = self.model(x)
            Y.append(result)
        return np.asarray(Y)

    def fit(self, X, Y):
        accuracy = {}

        for b in range(X.shape[1] + 1):
            self.b = b
            Y_pred = self.predict(X)
            accuracy[b] = accuracy_score(Y_pred, Y)

        best_b = max(accuracy, key = accuracy.get)
        self.b = best_b
        for i in range(4):
            print('value of b is ', i)
            print('Accuracy is ', accuracy[i])
        print('value of Optimal b is ', best_b)
        print('Highest accuracy is ', accuracy[best_b])

# %%
mp_neuron = MPNeuron()
mp_neuron.fit(X_binarised_train, Y_train)
# Out:
# value of b is  0
# Accuracy is  0.5085714285714286
# value of b is  1
# Accuracy is  0.5185714285714286
# value of b is  2
# Accuracy is  0.5128571428571429
# value of b is  3
# Accuracy is  0.4942857142857143
# value of Optimal b is  1
# Highest accuracy is  0.5185714285714286
